# %%
from segHelperLib import *
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W1030 12:03:38.449568 17784 deprecation_wrapper.py:119] From C:\Users\Zifeng Li\Desktop\HelmsleyDocker\Helmsley3DMIP\_Scripts\Utilities\manualSegHelper\test_model.py:4: The name tf.keras.layers.CuDNNGRU is deprecated. Please use tf.compat.v1.keras.layers.CuDNNGRU instead.
#
# W1030 12:03:38.452573 17784 deprecation_wrapper.py:119] From C:\Users\Zifeng Li\Desktop\HelmsleyDocker\Helmsley3DMIP\_Scripts\Utilities\manualSegHelper\test_model.py:4: The name tf.keras.layers.CuDNNLSTM is deprecated. Please use tf.compat.v1.keras.layers.CuDNNLSTM instead.

# %%
# This variables are just temporary 
input_label_full_folder_path = "./toSegmentAnswer"
sampled_label_folder_path = "./sampledLabel"

# Run this block to prepare all the training data
pruneSystem()
sampleDicomData(0.3, 1)

# This sample is for sample the already segmented mask files. The user will use Slicer to create the sampled labels instead
sampleDicomData(1, 1, dicomPath=input_label_full_folder_path, outputPath=sampled_label_folder_path)

createTrainingData(1)
createTestingData(1)
# Out:
# Deleting old training files and temp files.
# Deleting directory ./sampledLabel failed
# Deleting directory ./tmp failed
# Successfully created the directory ./sampledDataset
# Sampling 55 dicom images.
# Successfully created the directory ./sampledLabel
# Sampling 55 dicom images.
# Creating training PNG files.
# Successfully created the directory ./tmp
# Successfully created the directory ./tmp/trainingImage
# Successfully created the directory ./tmp/trainingMask
#
#  Done! Converted 55 images and masks.
# Creating testing PNG files.
# Successfully created the directory ./tmp/testingImage
#
#  Done! Converted 164 images.

# %%
# Run this block to start the training process
trainUnet(COLOR_DICT, multiLabel=True)
# Out:
# W1030 12:03:49.712144 17784 deprecation.py:506] From C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\tensorflow\python\ops\init_ops.py:1288: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 9583548201791481966
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 6667611669
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 709106254491673302
# physical_device_desc: "device: 0, name: GeForce GTX 1080, pci bus id: 0000:01:00.0, compute capability: 6.1"
# ]
# W1030 12:03:50.861176 17784 deprecation.py:323] From C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\tensorflow\python\ops\nn_impl.py:180: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 256, 256, 64) 1792        input_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu (LeakyReLU)         (None, 256, 256, 64) 0           conv2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 256, 256, 64) 256         leaky_re_lu[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 256, 256, 64) 36928       batch_normalization[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)       (None, 256, 256, 64) 0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 256, 256, 64) 256         leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 128, 128, 64) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 128, 128, 128 73856       max_pooling2d[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)       (None, 128, 128, 128 0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 128, 128, 128 512         leaky_re_lu_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 128, 128, 128 147584      batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)       (None, 128, 128, 128 0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 128, 128, 128 512         leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 64, 64, 128)  0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 64, 64, 256)  295168      max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)       (None, 64, 64, 256)  0           conv2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 64, 64, 256)  1024        leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 64, 64, 256)  590080      batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)       (None, 64, 64, 256)  0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 64, 64, 256)  1024        leaky_re_lu_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 32, 32, 256)  0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 32, 32, 512)  1180160     max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)       (None, 32, 32, 512)  0           conv2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 32, 32, 512)  2048        leaky_re_lu_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 32, 32, 512)  2359808     batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)       (None, 32, 32, 512)  0           conv2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 32, 32, 512)  2048        leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 32, 32, 512)  0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 16, 16, 512)  0           dropout[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 16, 16, 1024) 4719616     max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)       (None, 16, 16, 1024) 0           conv2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 16, 16, 1024) 4096        leaky_re_lu_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 16, 16, 1024) 9438208     batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)       (None, 16, 16, 1024) 0           conv2d_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 16, 16, 1024) 4096        leaky_re_lu_9[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 16, 16, 1024) 0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# up_sampling2d (UpSampling2D)    (None, 32, 32, 1024) 0           dropout_1[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 32, 32, 512)  2097664     up_sampling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 32, 32, 512)  2048        conv2d_10[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 32, 32, 1024) 0           dropout[0][0]
#                                                                  batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 32, 32, 512)  4719104     concatenate[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 32, 32, 512)  2048        conv2d_11[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 32, 32, 512)  2359808     batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 32, 32, 512)  2048        conv2d_12[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, 64, 64, 512)  0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 64, 64, 256)  524544      up_sampling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 64, 64, 256)  1024        conv2d_13[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 64, 64, 512)  0           batch_normalization_5[0][0]
#                                                                  batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 64, 64, 256)  1179904     concatenate_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 64, 64, 256)  1024        conv2d_14[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 64, 64, 256)  590080      batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 64, 64, 256)  1024        conv2d_15[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (None, 128, 128, 256 0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 128, 128, 128 131200      up_sampling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 128, 128, 128 512         conv2d_16[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 128, 128, 256 0           batch_normalization_3[0][0]
#                                                                  batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 128, 128, 128 295040      concatenate_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 128, 128, 128 512         conv2d_17[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 128, 128, 128 147584      batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 128, 128, 128 512         conv2d_18[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_3 (UpSampling2D)  (None, 256, 256, 128 0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 256, 256, 64) 32832       up_sampling2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 256, 256, 64) 256         conv2d_19[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 256, 256, 128 0           batch_normalization_1[0][0]
#                                                                  batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 256, 256, 64) 73792       concatenate_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 256, 256, 64) 256         conv2d_20[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 256, 256, 64) 36928       batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 256, 256, 64) 256         conv2d_21[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 256, 256, 2)  1154        batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 256, 256, 2)  8           conv2d_22[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 256, 256, 2)  6           batch_normalization_22[0][0]
# ==================================================================================================
# Total params: 31,060,240
# Trainable params: 31,046,540
# Non-trainable params: 13,700
# __________________________________________________________________________________________________
# None
# Found 55 images belonging to 1 classes.
# Found 55 images belonging to 1 classes.
# Epoch 1/3
# 2048/2048 [==============================] - 667s 325ms/step - loss: 0.4076 - acc: 0.9823
# Epoch 2/3
# 2048/2048 [==============================] - 657s 321ms/step - loss: 0.2152 - acc: 0.9920
# Epoch 3/3
# 2048/2048 [==============================] - 658s 321ms/step - loss: 0.1076 - acc: 0.9935

# %%
# Run this block to generate predictions
# Put the name of the model you want to use in the parameter below.
testUnet(COLOR_DICT, "./model_archive/segmentation_10_30_12_03.hdf5", multiLabel=True)
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 13988025778903037370
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 6667611669
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 1328673106304886326
# physical_device_desc: "device: 0, name: GeForce GTX 1080, pci bus id: 0000:01:00.0, compute capability: 6.1"
# ]
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 256, 256, 64) 1792        input_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_10 (LeakyReLU)      (None, 256, 256, 64) 0           conv2d_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 256, 256, 64) 256         leaky_re_lu_10[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 256, 256, 64) 36928       batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_11 (LeakyReLU)      (None, 256, 256, 64) 0           conv2d_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 256, 256, 64) 256         leaky_re_lu_11[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 128, 128, 64) 0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 128, 128, 128 73856       max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_12 (LeakyReLU)      (None, 128, 128, 128 0           conv2d_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 128, 128, 128 512         leaky_re_lu_12[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 128, 128, 128 147584      batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_13 (LeakyReLU)      (None, 128, 128, 128 0           conv2d_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 128, 128, 128 512         leaky_re_lu_13[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 64, 64, 128)  0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 64, 64, 256)  295168      max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_14 (LeakyReLU)      (None, 64, 64, 256)  0           conv2d_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 64, 64, 256)  1024        leaky_re_lu_14[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 64, 64, 256)  590080      batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_15 (LeakyReLU)      (None, 64, 64, 256)  0           conv2d_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 64, 64, 256)  1024        leaky_re_lu_15[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_6 (MaxPooling2D)  (None, 32, 32, 256)  0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 32, 32, 512)  1180160     max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_16 (LeakyReLU)      (None, 32, 32, 512)  0           conv2d_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 32, 32, 512)  2048        leaky_re_lu_16[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 32, 32, 512)  2359808     batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_17 (LeakyReLU)      (None, 32, 32, 512)  0           conv2d_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 32, 32, 512)  2048        leaky_re_lu_17[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 32, 32, 512)  0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_7 (MaxPooling2D)  (None, 16, 16, 512)  0           dropout_2[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 16, 16, 1024) 4719616     max_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_18 (LeakyReLU)      (None, 16, 16, 1024) 0           conv2d_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 16, 16, 1024) 4096        leaky_re_lu_18[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 16, 16, 1024) 9438208     batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_19 (LeakyReLU)      (None, 16, 16, 1024) 0           conv2d_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 16, 16, 1024) 4096        leaky_re_lu_19[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 16, 16, 1024) 0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_4 (UpSampling2D)  (None, 32, 32, 1024) 0           dropout_3[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 32, 32, 512)  2097664     up_sampling2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 32, 32, 512)  2048        conv2d_34[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 32, 32, 1024) 0           dropout_2[0][0]
#                                                                  batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 32, 32, 512)  4719104     concatenate_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 32, 32, 512)  2048        conv2d_35[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 32, 32, 512)  2359808     batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 32, 32, 512)  2048        conv2d_36[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_5 (UpSampling2D)  (None, 64, 64, 512)  0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 64, 64, 256)  524544      up_sampling2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 64, 64, 256)  1024        conv2d_37[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 64, 64, 512)  0           batch_normalization_28[0][0]
#                                                                  batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 64, 64, 256)  1179904     concatenate_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 64, 64, 256)  1024        conv2d_38[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 64, 64, 256)  590080      batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 64, 64, 256)  1024        conv2d_39[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_6 (UpSampling2D)  (None, 128, 128, 256 0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 128, 128, 128 131200      up_sampling2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 128, 128, 128 512         conv2d_40[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 128, 128, 256 0           batch_normalization_26[0][0]
#                                                                  batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 128, 128, 128 295040      concatenate_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 128, 128, 128 512         conv2d_41[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 128, 128, 128 147584      batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 128, 128, 128 512         conv2d_42[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_7 (UpSampling2D)  (None, 256, 256, 128 0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 256, 256, 64) 32832       up_sampling2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 256, 256, 64) 256         conv2d_43[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 256, 256, 128 0           batch_normalization_24[0][0]
#                                                                  batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 256, 256, 64) 73792       concatenate_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 256, 256, 64) 256         conv2d_44[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 256, 256, 64) 36928       batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 256, 256, 64) 256         conv2d_45[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 256, 256, 2)  1154        batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 256, 256, 2)  8           conv2d_46[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 256, 256, 2)  6           batch_normalization_45[0][0]
# ==================================================================================================
# Total params: 31,060,240
# Trainable params: 31,046,540
# Non-trainable params: 13,700
# __________________________________________________________________________________________________
# None
# 164/164 [==============================] - 6s 38ms/step
# Successfully created the directory ./predicted_segmnetation_10_30_12_39
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_10_30_12_39\0.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# W1030 12:39:38.055177 17784 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_10_30_12_39\1.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# W1030 12:39:38.117138 17784 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_10_30_12_39\2.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# W1030 12:39:38.183140 17784 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_10_30_12_39\3.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# W1030 12:39:38.248140 17784 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_10_30_12_39\4.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# W1030 12:39:38.309139 17784 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_10_30_12_39\5.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# W1030 12:39:38.370140 17784 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_10_30_12_39\6.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# W1030 12:39:38.431165 17784 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_10_30_12_39\7.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# W1030 12:39:38.491139 17784 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_10_30_12_39\8.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# W1030 12:39:38.551140 17784 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_10_30_12_39\9.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# W1030 12:39:38.611140 17784 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_10_30_12_39\10.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# W1030 12:39:38.671170 17784 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_10_30_12_39\11.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# W1030 12:39:38.730175 17784 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_10_30_12_39\12.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# W1030 12:39:38.788139 17784 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_10_30_12_39\13.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# W1030 12:39:38.847170 17784 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_10_30_12_39\14.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# W1030 12:39:38.907169 17784 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_10_30_12_39\15.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# W1030 12:39:38.965168 17784 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_10_30_12_39\16.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# W1030 12:39:39.027170 17784 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_10_30_12_39\17.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# W1030 12:39:39.093140 17784 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_10_30_12_39\18.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# W1030 12:39:39.170138 17784 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_10_30_12_39\19.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# W1030 12:39:39.234139 17784 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_10_30_12_39\20.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# W1030 12:39:39.295139 17784 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_10_30_12_39\21.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# W1030 12:39:39.358140 17784 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_10_30_12_39\22.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# W1030 12:39:39.421140 17784 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_10_30_12_39\23.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# W1030 12:39:39.482140 17784 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_10_30_12_39\24.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# W1030 12:39:39.546139 17784 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_10_30_12_39\25.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# W1030 12:39:39.611139 17784 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_10_30_12_39\26.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# W1030 12:39:39.671139 17784 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W1030 12:39:39.734142 17784 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W1030 12:39:39.798184 17784 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W1030 12:39:39.860164 17784 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W1030 12:39:39.932167 17784 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W1030 12:39:40.000171 17784 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W1030 12:39:40.066138 17784 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W1030 12:39:40.129141 17784 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W1030 12:39:40.191139 17784 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W1030 12:39:40.254140 17784 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W1030 12:39:40.316139 17784 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W1030 12:39:40.380176 17784 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W1030 12:39:40.443140 17784 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W1030 12:39:40.507139 17784 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W1030 12:39:40.571138 17784 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W1030 12:39:40.638168 17784 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W1030 12:39:40.702176 17784 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W1030 12:39:40.767161 17784 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W1030 12:39:40.833139 17784 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W1030 12:39:40.899161 17784 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W1030 12:39:40.968177 17784 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W1030 12:39:41.034162 17784 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W1030 12:39:41.101170 17784 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W1030 12:39:41.169169 17784 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W1030 12:39:41.236175 17784 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W1030 12:39:41.303176 17784 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W1030 12:39:41.368139 17784 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W1030 12:39:41.437174 17784 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W1030 12:39:41.509169 17784 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W1030 12:39:41.578166 17784 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W1030 12:39:41.649140 17784 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W1030 12:39:41.722138 17784 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W1030 12:39:41.792139 17784 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W1030 12:39:41.860171 17784 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W1030 12:39:41.928140 17784 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W1030 12:39:41.997140 17784 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W1030 12:39:42.097138 17784 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W1030 12:39:42.170139 17784 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W1030 12:39:42.241140 17784 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W1030 12:39:42.310138 17784 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W1030 12:39:42.379172 17784 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W1030 12:39:42.451170 17784 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W1030 12:39:42.524141 17784 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W1030 12:39:42.607139 17784 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W1030 12:39:42.683143 17784 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W1030 12:39:42.755168 17784 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W1030 12:39:42.831139 17784 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W1030 12:39:42.906170 17784 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W1030 12:39:42.983141 17784 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W1030 12:39:43.055139 17784 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W1030 12:39:43.128170 17784 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W1030 12:39:43.201175 17784 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W1030 12:39:43.274168 17784 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W1030 12:39:43.349142 17784 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W1030 12:39:43.422171 17784 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W1030 12:39:43.494177 17784 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W1030 12:39:43.568139 17784 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W1030 12:39:43.640174 17784 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W1030 12:39:43.712207 17784 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W1030 12:39:43.787178 17784 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W1030 12:39:43.858214 17784 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W1030 12:39:43.929215 17784 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W1030 12:39:44.001181 17784 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W1030 12:39:44.081208 17784 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W1030 12:39:44.158187 17784 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W1030 12:39:44.233178 17784 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W1030 12:39:44.307215 17784 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W1030 12:39:44.381178 17784 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W1030 12:39:44.455182 17784 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W1030 12:39:44.528216 17784 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W1030 12:39:44.606178 17784 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W1030 12:39:44.688177 17784 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W1030 12:39:44.764180 17784 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W1030 12:39:44.841178 17784 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W1030 12:39:44.917210 17784 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W1030 12:39:44.992178 17784 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W1030 12:39:45.072217 17784 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W1030 12:39:45.144177 17784 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W1030 12:39:45.236178 17784 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W1030 12:39:45.318177 17784 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W1030 12:39:45.388177 17784 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W1030 12:39:45.462177 17784 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W1030 12:39:45.535177 17784 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W1030 12:39:45.606178 17784 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W1030 12:39:45.678177 17784 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W1030 12:39:45.755176 17784 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W1030 12:39:45.825207 17784 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W1030 12:39:45.899207 17784 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W1030 12:39:45.973178 17784 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W1030 12:39:46.042176 17784 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W1030 12:39:46.113177 17784 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W1030 12:39:46.186209 17784 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W1030 12:39:46.255176 17784 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W1030 12:39:46.330204 17784 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W1030 12:39:46.413184 17784 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W1030 12:39:46.490208 17784 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W1030 12:39:46.561178 17784 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W1030 12:39:46.631177 17784 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W1030 12:39:46.702213 17784 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W1030 12:39:46.780177 17784 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W1030 12:39:46.855177 17784 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W1030 12:39:46.926177 17784 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W1030 12:39:46.997176 17784 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W1030 12:39:47.069179 17784 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W1030 12:39:47.140178 17784 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W1030 12:39:47.206176 17784 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W1030 12:39:47.274177 17784 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W1030 12:39:47.365178 17784 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W1030 12:39:47.434178 17784 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W1030 12:39:47.518178 17784 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W1030 12:39:47.590177 17784 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W1030 12:39:47.656178 17784 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W1030 12:39:47.734177 17784 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W1030 12:39:47.815178 17784 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W1030 12:39:47.896178 17784 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W1030 12:39:47.980179 17784 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W1030 12:39:48.052181 17784 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W1030 12:39:48.123191 17784 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W1030 12:39:48.192177 17784 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W1030 12:39:48.263177 17784 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W1030 12:39:48.330180 17784 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W1030 12:39:48.405177 17784 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W1030 12:39:48.484179 17784 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W1030 12:39:48.554211 17784 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W1030 12:39:48.619207 17784 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W1030 12:39:48.687187 17784 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W1030 12:39:48.761210 17784 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W1030 12:39:48.826210 17784 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W1030 12:39:48.891178 17784 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W1030 12:39:48.970178 17784 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W1030 12:39:49.034178 17784 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W1030 12:39:49.096178 17784 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_10_30_12_39\158.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# W1030 12:39:49.170186 17784 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_10_30_12_39\159.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# W1030 12:39:49.241179 17784 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_10_30_12_39\160.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# W1030 12:39:49.305215 17784 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_10_30_12_39\161.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# W1030 12:39:49.365180 17784 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_10_30_12_39\162.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# W1030 12:39:49.428177 17784 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_10_30_12_39\163.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# W1030 12:39:49.493177 17784 util.py:64] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.

# %%
# Run this block to clean up every thing
pruneSystem()
# Out:
# Deleting old training files and temp files.
