# %%
from segHelperLib import *
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0911 17:06:07.477129 18156 deprecation_wrapper.py:119] From C:\Users\Zifeng Li\Desktop\HelmsleyDocker\Helmsley3DMIP\_Scripts\Utilities\manualSegHelper\test_model.py:4: The name tf.keras.layers.CuDNNGRU is deprecated. Please use tf.compat.v1.keras.layers.CuDNNGRU instead.
#
# W0911 17:06:07.480099 18156 deprecation_wrapper.py:119] From C:\Users\Zifeng Li\Desktop\HelmsleyDocker\Helmsley3DMIP\_Scripts\Utilities\manualSegHelper\test_model.py:4: The name tf.keras.layers.CuDNNLSTM is deprecated. Please use tf.compat.v1.keras.layers.CuDNNLSTM instead.

# %%
# This variables are just temporary 
input_label_full_folder_path = "./toSegmentAnswer"
sampled_label_folder_path = "./sampledLabel"

# Run this block to prepare all the training data
pruneSystem()
sampleDicomData(0.3)

# This sample is for sample the already segmented mask files. The user will use Slicer to create the sampled labels instead
sampleDicomData(1, dicomPath=input_label_full_folder_path, outputPath=sampled_label_folder_path)

createTrainingData()
createTestingData()
# Out:
# Deleting old training files and temp files.
# Successfully created the directory ./sampledDataset
# Sampling 39 dicom images.
# Successfully created the directory ./sampledLabel
# Sampling 39 dicom images.
# Creating training PNG files.
# Successfully created the directory ./tmp
# Successfully created the directory ./tmp/trainingImage
# Successfully created the directory ./tmp/trainingMask
#
#  Done! Converted 39 images and masks.
# Creating testing PNG files.
# Successfully created the directory ./tmp/testingImage
#
#  Done! Converted 116 images.

# %%
# Run this block to start the training process
trainUnet(COLOR_DICT, multiLabel=True)
# Out:
# W0911 17:06:13.735243 18156 deprecation.py:506] From C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\tensorflow\python\ops\init_ops.py:1288: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 2394285559430530233
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 6667611669
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 11624819292327489330
# physical_device_desc: "device: 0, name: GeForce GTX 1080, pci bus id: 0000:01:00.0, compute capability: 6.1"
# ]
# W0911 17:06:14.943243 18156 deprecation.py:323] From C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\tensorflow\python\ops\nn_impl.py:180: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 256, 256, 64) 1792        input_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu (LeakyReLU)         (None, 256, 256, 64) 0           conv2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 256, 256, 64) 256         leaky_re_lu[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 256, 256, 64) 36928       batch_normalization[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)       (None, 256, 256, 64) 0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 256, 256, 64) 256         leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 128, 128, 64) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 128, 128, 128 73856       max_pooling2d[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)       (None, 128, 128, 128 0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 128, 128, 128 512         leaky_re_lu_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 128, 128, 128 147584      batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)       (None, 128, 128, 128 0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 128, 128, 128 512         leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 64, 64, 128)  0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 64, 64, 256)  295168      max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)       (None, 64, 64, 256)  0           conv2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 64, 64, 256)  1024        leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 64, 64, 256)  590080      batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)       (None, 64, 64, 256)  0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 64, 64, 256)  1024        leaky_re_lu_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 32, 32, 256)  0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 32, 32, 512)  1180160     max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)       (None, 32, 32, 512)  0           conv2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 32, 32, 512)  2048        leaky_re_lu_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 32, 32, 512)  2359808     batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)       (None, 32, 32, 512)  0           conv2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 32, 32, 512)  2048        leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 32, 32, 512)  0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 16, 16, 512)  0           dropout[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 16, 16, 1024) 4719616     max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)       (None, 16, 16, 1024) 0           conv2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 16, 16, 1024) 4096        leaky_re_lu_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 16, 16, 1024) 9438208     batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)       (None, 16, 16, 1024) 0           conv2d_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 16, 16, 1024) 4096        leaky_re_lu_9[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 16, 16, 1024) 0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# up_sampling2d (UpSampling2D)    (None, 32, 32, 1024) 0           dropout_1[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 32, 32, 512)  2097664     up_sampling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 32, 32, 512)  2048        conv2d_10[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 32, 32, 1024) 0           dropout[0][0]
#                                                                  batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 32, 32, 512)  4719104     concatenate[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 32, 32, 512)  2048        conv2d_11[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 32, 32, 512)  2359808     batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 32, 32, 512)  2048        conv2d_12[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, 64, 64, 512)  0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 64, 64, 256)  524544      up_sampling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 64, 64, 256)  1024        conv2d_13[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 64, 64, 512)  0           batch_normalization_5[0][0]
#                                                                  batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 64, 64, 256)  1179904     concatenate_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 64, 64, 256)  1024        conv2d_14[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 64, 64, 256)  590080      batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 64, 64, 256)  1024        conv2d_15[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (None, 128, 128, 256 0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 128, 128, 128 131200      up_sampling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 128, 128, 128 512         conv2d_16[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 128, 128, 256 0           batch_normalization_3[0][0]
#                                                                  batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 128, 128, 128 295040      concatenate_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 128, 128, 128 512         conv2d_17[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 128, 128, 128 147584      batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 128, 128, 128 512         conv2d_18[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_3 (UpSampling2D)  (None, 256, 256, 128 0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 256, 256, 64) 32832       up_sampling2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 256, 256, 64) 256         conv2d_19[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 256, 256, 128 0           batch_normalization_1[0][0]
#                                                                  batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 256, 256, 64) 73792       concatenate_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 256, 256, 64) 256         conv2d_20[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 256, 256, 64) 36928       batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 256, 256, 64) 256         conv2d_21[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 256, 256, 2)  1154        batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 256, 256, 2)  8           conv2d_22[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 256, 256, 2)  6           batch_normalization_22[0][0]
# ==================================================================================================
# Total params: 31,060,240
# Trainable params: 31,046,540
# Non-trainable params: 13,700
# __________________________________________________________________________________________________
# None
# Found 36 images belonging to 1 classes.
# Found 36 images belonging to 1 classes.
# Epoch 1/3
# 2048/2048 [==============================] - 688s 336ms/step - loss: 0.6066 - acc: 0.8734
# Epoch 2/3
# 1350/2048 [==================>...........] - ETA: 3:55 - loss: 0.4340 - acc: 0.9977
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-c5433b402999> in <module>
#       1 # Run this block to start the training process
# ----> 2 trainUnet(COLOR_DICT, multiLabel=True)
#
# ~\Desktop\HelmsleyDocker\Helmsley3DMIP\_Scripts\Utilities\manualSegHelper\trainUnet.py in trainUnet(colorDict, multiLabel)
#      55         The training starts here.
#      56 	'''
# ---> 57         model.fit_generator(myGene,steps_per_epoch=2048,epochs=3)
#      58
#      59         if(cpuModel):
#
# ~\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\tensorflow\python\keras\engine\training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1431         shuffle=shuffle,
#    1432         initial_epoch=initial_epoch,
# -> 1433         steps_name='steps_per_epoch')
#    1434
#    1435   def evaluate_generator(self,
#
# ~\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\tensorflow\python\keras\engine\training_generator.py in model_iteration(model, data, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch, mode, batch_size, steps_name, **kwargs)
#     218     step = 0
#     219     while step < target_steps:
# --> 220       batch_data = _get_next_batch(generator, mode)
#     221       if batch_data is None:
#     222         if is_dataset:
#
# ~\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\tensorflow\python\keras\engine\training_generator.py in _get_next_batch(generator, mode)
#     360   """Retrieves the next batch of input data."""
#     361   try:
# --> 362     generator_output = next(generator)
#     363   except (StopIteration, errors.OutOfRangeError):
#     364     return None
#
# ~\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\tensorflow\python\keras\utils\data_utils.py in get(self)
#     916             'Keras requires a thread-safe generator when '
#     917             '`use_multiprocessing=False, workers > 1`. ')
# --> 918       six.reraise(*sys.exc_info())
#
# ~\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\six.py in reraise(tp, value, tb)
#     691             if value.__traceback__ is not tb:
#     692                 raise value.with_traceback(tb)
# --> 693             raise value
#     694         finally:
#     695             value = None
#
# ~\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\tensorflow\python\keras\utils\data_utils.py in get(self)
#     892     try:
#     893       while self.is_running():
# --> 894         inputs = self.queue.get(block=True).get()
#     895         self.queue.task_done()
#     896         if inputs is not None:
#
# ~\Anaconda3\envs\Helmsley3DMIP\lib\multiprocessing\pool.py in get(self, timeout)
#     642             return self._value
#     643         else:
# --> 644             raise self._value
#     645
#     646     def _set(self, i, obj):
#
# ~\Anaconda3\envs\Helmsley3DMIP\lib\multiprocessing\pool.py in worker(inqueue, outqueue, initializer, initargs, maxtasks, wrap_exception)
#     117         job, i, func, args, kwds = task
#     118         try:
# --> 119             result = (True, func(*args, **kwds))
#     120         except Exception as e:
#     121             if wrap_exception and func is not _helper_reraises_exception:
#
# ~\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\tensorflow\python\keras\utils\data_utils.py in next_sample(uid)
#     826       The next value of generator `uid`.
#     827   """
# --> 828   return six.next(_SHARED_SEQUENCES[uid])
#     829
#     830
#
# ~\Desktop\HelmsleyDocker\Helmsley3DMIP\_Scripts\Utilities\manualSegHelper\data.py in trainGenerator(batch_size, train_path, image_folder, mask_folder, aug_dict, organ_color_dict, image_color_mode, mask_color_mode, image_save_prefix, mask_save_prefix, multi_label, num_class, save_to_dir, target_size, seed)
#      62         seed = seed)
#      63     train_generator = zip(image_generator, mask_generator)
# ---> 64     for (img,mask) in train_generator:
#      65         img,mask = adjustData(img,mask, organ_color_dict)
#      66         yield (img,mask)
#
# ~\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\keras_preprocessing\image\iterator.py in __next__(self, *args, **kwargs)
#     102
#     103     def __next__(self, *args, **kwargs):
# --> 104         return self.next(*args, **kwargs)
#     105
#     106     def next(self):
#
# ~\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\keras_preprocessing\image\iterator.py in next(self)
#     114         # The transformation of images is not under thread lock
#     115         # so it can be done in parallel
# --> 116         return self._get_batches_of_transformed_samples(index_array)
#     117
#     118     def _get_batches_of_transformed_samples(self, index_array):
#
# ~\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\keras_preprocessing\image\iterator.py in _get_batches_of_transformed_samples(self, index_array)
#     228                            color_mode=self.color_mode,
#     229                            target_size=self.target_size,
# --> 230                            interpolation=self.interpolation)
#     231             x = img_to_array(img, data_format=self.data_format)
#     232             # Pillow images should be closed after `load_img`,
#
# ~\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\keras_preprocessing\image\utils.py in load_img(path, grayscale, color_mode, target_size, interpolation)
#     108         raise ImportError('Could not import PIL.Image. '
#     109                           'The use of `load_img` requires PIL.')
# --> 110     img = pil_image.open(path)
#     111     if color_mode == 'grayscale':
#     112         if img.mode != 'L':
#
# ~\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\PIL\Image.py in open(fp, mode)
#    2650
#    2651     if filename:
# -> 2652         fp = builtins.open(filename, "rb")
#    2653         exclusive_fp = True
#    2654
#
# FileNotFoundError: [Errno 2] No such file or directory: 'tmp\\trainingImage\\25.png'

# %%
# Run this block to generate predictions
# Put the name of the model you want to use in the parameter below.
testUnet(COLOR_DICT, "./model_archive/segmentation_09_11_16_18_2016_splean.hdf5", multiLabel=True)
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 17478196701896006289
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 6667611669
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 17704586189918796941
# physical_device_desc: "device: 0, name: GeForce GTX 1080, pci bus id: 0000:01:00.0, compute capability: 6.1"
# ]
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 256, 256, 64) 1792        input_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_20 (LeakyReLU)      (None, 256, 256, 64) 0           conv2d_48[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 256, 256, 64) 256         leaky_re_lu_20[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 256, 256, 64) 36928       batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_21 (LeakyReLU)      (None, 256, 256, 64) 0           conv2d_49[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 256, 256, 64) 256         leaky_re_lu_21[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_8 (MaxPooling2D)  (None, 128, 128, 64) 0           batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 128, 128, 128 73856       max_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_22 (LeakyReLU)      (None, 128, 128, 128 0           conv2d_50[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 128, 128, 128 512         leaky_re_lu_22[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 128, 128, 128 147584      batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_23 (LeakyReLU)      (None, 128, 128, 128 0           conv2d_51[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 128, 128, 128 512         leaky_re_lu_23[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_9 (MaxPooling2D)  (None, 64, 64, 128)  0           batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 64, 64, 256)  295168      max_pooling2d_9[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_24 (LeakyReLU)      (None, 64, 64, 256)  0           conv2d_52[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 64, 64, 256)  1024        leaky_re_lu_24[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 64, 64, 256)  590080      batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_25 (LeakyReLU)      (None, 64, 64, 256)  0           conv2d_53[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 64, 64, 256)  1024        leaky_re_lu_25[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_10 (MaxPooling2D) (None, 32, 32, 256)  0           batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 32, 32, 512)  1180160     max_pooling2d_10[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_26 (LeakyReLU)      (None, 32, 32, 512)  0           conv2d_54[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, 32, 32, 512)  2048        leaky_re_lu_26[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 32, 32, 512)  2359808     batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_27 (LeakyReLU)      (None, 32, 32, 512)  0           conv2d_55[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, 32, 32, 512)  2048        leaky_re_lu_27[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 32, 32, 512)  0           batch_normalization_53[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_11 (MaxPooling2D) (None, 16, 16, 512)  0           dropout_4[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 16, 16, 1024) 4719616     max_pooling2d_11[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_28 (LeakyReLU)      (None, 16, 16, 1024) 0           conv2d_56[0][0]
# __________________________________________________________________________________________________
# batch_normalization_54 (BatchNo (None, 16, 16, 1024) 4096        leaky_re_lu_28[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, 16, 16, 1024) 9438208     batch_normalization_54[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_29 (LeakyReLU)      (None, 16, 16, 1024) 0           conv2d_57[0][0]
# __________________________________________________________________________________________________
# batch_normalization_55 (BatchNo (None, 16, 16, 1024) 4096        leaky_re_lu_29[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 16, 16, 1024) 0           batch_normalization_55[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_8 (UpSampling2D)  (None, 32, 32, 1024) 0           dropout_5[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, 32, 32, 512)  2097664     up_sampling2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_56 (BatchNo (None, 32, 32, 512)  2048        conv2d_58[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 32, 32, 1024) 0           dropout_4[0][0]
#                                                                  batch_normalization_56[0][0]
# __________________________________________________________________________________________________
# conv2d_59 (Conv2D)              (None, 32, 32, 512)  4719104     concatenate_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_57 (BatchNo (None, 32, 32, 512)  2048        conv2d_59[0][0]
# __________________________________________________________________________________________________
# conv2d_60 (Conv2D)              (None, 32, 32, 512)  2359808     batch_normalization_57[0][0]
# __________________________________________________________________________________________________
# batch_normalization_58 (BatchNo (None, 32, 32, 512)  2048        conv2d_60[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_9 (UpSampling2D)  (None, 64, 64, 512)  0           batch_normalization_58[0][0]
# __________________________________________________________________________________________________
# conv2d_61 (Conv2D)              (None, 64, 64, 256)  524544      up_sampling2d_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_59 (BatchNo (None, 64, 64, 256)  1024        conv2d_61[0][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, 64, 64, 512)  0           batch_normalization_51[0][0]
#                                                                  batch_normalization_59[0][0]
# __________________________________________________________________________________________________
# conv2d_62 (Conv2D)              (None, 64, 64, 256)  1179904     concatenate_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_60 (BatchNo (None, 64, 64, 256)  1024        conv2d_62[0][0]
# __________________________________________________________________________________________________
# conv2d_63 (Conv2D)              (None, 64, 64, 256)  590080      batch_normalization_60[0][0]
# __________________________________________________________________________________________________
# batch_normalization_61 (BatchNo (None, 64, 64, 256)  1024        conv2d_63[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_10 (UpSampling2D) (None, 128, 128, 256 0           batch_normalization_61[0][0]
# __________________________________________________________________________________________________
# conv2d_64 (Conv2D)              (None, 128, 128, 128 131200      up_sampling2d_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_62 (BatchNo (None, 128, 128, 128 512         conv2d_64[0][0]
# __________________________________________________________________________________________________
# concatenate_10 (Concatenate)    (None, 128, 128, 256 0           batch_normalization_49[0][0]
#                                                                  batch_normalization_62[0][0]
# __________________________________________________________________________________________________
# conv2d_65 (Conv2D)              (None, 128, 128, 128 295040      concatenate_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_63 (BatchNo (None, 128, 128, 128 512         conv2d_65[0][0]
# __________________________________________________________________________________________________
# conv2d_66 (Conv2D)              (None, 128, 128, 128 147584      batch_normalization_63[0][0]
# __________________________________________________________________________________________________
# batch_normalization_64 (BatchNo (None, 128, 128, 128 512         conv2d_66[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_11 (UpSampling2D) (None, 256, 256, 128 0           batch_normalization_64[0][0]
# __________________________________________________________________________________________________
# conv2d_67 (Conv2D)              (None, 256, 256, 64) 32832       up_sampling2d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_65 (BatchNo (None, 256, 256, 64) 256         conv2d_67[0][0]
# __________________________________________________________________________________________________
# concatenate_11 (Concatenate)    (None, 256, 256, 128 0           batch_normalization_47[0][0]
#                                                                  batch_normalization_65[0][0]
# __________________________________________________________________________________________________
# conv2d_68 (Conv2D)              (None, 256, 256, 64) 73792       concatenate_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_66 (BatchNo (None, 256, 256, 64) 256         conv2d_68[0][0]
# __________________________________________________________________________________________________
# conv2d_69 (Conv2D)              (None, 256, 256, 64) 36928       batch_normalization_66[0][0]
# __________________________________________________________________________________________________
# batch_normalization_67 (BatchNo (None, 256, 256, 64) 256         conv2d_69[0][0]
# __________________________________________________________________________________________________
# conv2d_70 (Conv2D)              (None, 256, 256, 2)  1154        batch_normalization_67[0][0]
# __________________________________________________________________________________________________
# batch_normalization_68 (BatchNo (None, 256, 256, 2)  8           conv2d_70[0][0]
# __________________________________________________________________________________________________
# conv2d_71 (Conv2D)              (None, 256, 256, 2)  6           batch_normalization_68[0][0]
# ==================================================================================================
# Total params: 31,060,240
# Trainable params: 31,046,540
# Non-trainable params: 13,700
# __________________________________________________________________________________________________
# None
# 144/144 [==============================] - 5s 37ms/step
# Successfully created the directory ./predicted_segmnetation_09_11_16_54
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_11_16_54\0.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_11_16_54\1.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_11_16_54\2.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_11_16_54\3.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_11_16_54\4.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_11_16_54\5.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_11_16_54\6.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_11_16_54\7.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_11_16_54\8.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_11_16_54\9.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_11_16_54\10.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_11_16_54\11.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_11_16_54\12.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_11_16_54\13.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_11_16_54\14.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_11_16_54\15.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_11_16_54\16.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_11_16_54\17.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_11_16_54\18.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_11_16_54\19.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_11_16_54\20.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_11_16_54\21.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_11_16_54\22.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_11_16_54\23.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_11_16_54\24.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_11_16_54\25.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_11_16_54\26.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_11_16_54\27.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_11_16_54\28.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_11_16_54\29.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_11_16_54\30.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_11_16_54\31.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_11_16_54\32.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_11_16_54\33.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_11_16_54\34.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_11_16_54\35.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_11_16_54\36.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_11_16_54\37.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_11_16_54\38.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_11_16_54\39.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_11_16_54\40.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_11_16_54\41.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_11_16_54\42.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_11_16_54\43.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_11_16_54\44.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_11_16_54\45.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_11_16_54\46.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_11_16_54\47.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_11_16_54\48.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_11_16_54\49.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_11_16_54\50.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_11_16_54\51.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_11_16_54\52.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_11_16_54\53.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_11_16_54\54.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_11_16_54\55.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_11_16_54\56.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_11_16_54\57.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_11_16_54\58.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_11_16_54\59.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_11_16_54\60.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_11_16_54\61.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_11_16_54\62.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_11_16_54\63.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_11_16_54\64.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_11_16_54\65.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_11_16_54\66.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_11_16_54\67.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_11_16_54\68.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_11_16_54\69.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_11_16_54\70.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_11_16_54\71.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_11_16_54\72.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_11_16_54\73.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_11_16_54\74.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_11_16_54\75.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_11_16_54\76.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_11_16_54\77.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_11_16_54\78.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_11_16_54\79.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_11_16_54\80.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_11_16_54\81.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_11_16_54\82.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_11_16_54\83.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_11_16_54\84.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_11_16_54\85.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_11_16_54\86.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_11_16_54\87.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_11_16_54\88.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_11_16_54\89.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_11_16_54\90.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_11_16_54\91.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_11_16_54\92.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_11_16_54\93.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_11_16_54\94.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_11_16_54\95.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_11_16_54\96.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_11_16_54\97.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_11_16_54\98.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_11_16_54\99.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_11_16_54\100.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_11_16_54\101.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_11_16_54\102.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_11_16_54\103.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_11_16_54\104.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_11_16_54\105.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_11_16_54\106.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_11_16_54\107.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_11_16_54\108.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_11_16_54\109.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_11_16_54\110.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_11_16_54\111.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_11_16_54\112.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_11_16_54\113.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_11_16_54\114.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_11_16_54\115.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_11_16_54\116.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_11_16_54\117.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_11_16_54\118.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_11_16_54\119.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_11_16_54\120.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_11_16_54\121.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_11_16_54\122.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_11_16_54\123.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_11_16_54\124.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_11_16_54\125.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_11_16_54\126.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_11_16_54\127.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_11_16_54\128.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_11_16_54\129.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_11_16_54\130.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_11_16_54\131.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_11_16_54\132.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_11_16_54\133.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_11_16_54\134.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_11_16_54\135.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_11_16_54\136.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_11_16_54\137.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_11_16_54\138.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_11_16_54\139.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_11_16_54\140.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_11_16_54\141.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_11_16_54\142.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_11_16_54\143.png is a low contrast image
#   warn('%s is a low contrast image' % fname)

# %%
# Run this block to clean up every thing
pruneSystem()
# Out:
# Deleting old training files and temp files.
