# %%
from segHelperLib import *
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0903 16:01:40.536365 10540 deprecation_wrapper.py:119] From C:\Users\Zifeng Li\Desktop\HelmsleyDocker\Helmsley3DMIP\_Scripts\Utilities\manualSegHelper\test_model.py:4: The name tf.keras.layers.CuDNNGRU is deprecated. Please use tf.compat.v1.keras.layers.CuDNNGRU instead.
#
# W0903 16:01:40.538364 10540 deprecation_wrapper.py:119] From C:\Users\Zifeng Li\Desktop\HelmsleyDocker\Helmsley3DMIP\_Scripts\Utilities\manualSegHelper\test_model.py:4: The name tf.keras.layers.CuDNNLSTM is deprecated. Please use tf.compat.v1.keras.layers.CuDNNLSTM instead.

# %%
# Run this block to prepare all the training data
pruneSystem()
sampleDicomData(0.25)

# This sample is for sample the already segmented mask files. The user will use Slicer to create the sampled labels instead
samplePngData(0.25, ".\mri_label_2017_multilabel\*.png", "./sampledLabel")

createTrainingData(maskDicomPath=".\sampledLabel\*.png", usePng = True)
createTestingData()
# Out:
# Deleting old training files and temp files.
# Successfully created the directory ./sampledDataset
# Sampling 29 dicom images.
# Successfully created the directory ./sampledLabel
# Sampling 29 png images.
# Creating training PNG files.
# Successfully created the directory ./tmp
# Successfully created the directory ./tmp/trainingImage
# Successfully created the directory ./tmp/trainingMask
#
#  Done! Converted 29 images and masks.
# Creating testing PNG files.
# Successfully created the directory ./tmp/testingImage
#
#  Done! Converted 116 images.

# %%
# Run this block to start the training process
trainUnet(COLOR_DICT, multiLabel=True)
# Out:
# W0903 16:01:45.617370 10540 deprecation.py:506] From C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\tensorflow\python\ops\init_ops.py:1288: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 15036975769203426254
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 6667611669
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 1024251214324185328
# physical_device_desc: "device: 0, name: GeForce GTX 1080, pci bus id: 0000:01:00.0, compute capability: 6.1"
# ]
# W0903 16:01:46.781371 10540 deprecation.py:323] From C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\tensorflow\python\ops\nn_impl.py:180: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 256, 256, 64) 1792        input_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu (LeakyReLU)         (None, 256, 256, 64) 0           conv2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 256, 256, 64) 256         leaky_re_lu[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 256, 256, 64) 36928       batch_normalization[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)       (None, 256, 256, 64) 0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 256, 256, 64) 256         leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 128, 128, 64) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 128, 128, 128 73856       max_pooling2d[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)       (None, 128, 128, 128 0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 128, 128, 128 512         leaky_re_lu_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 128, 128, 128 147584      batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)       (None, 128, 128, 128 0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 128, 128, 128 512         leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 64, 64, 128)  0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 64, 64, 256)  295168      max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)       (None, 64, 64, 256)  0           conv2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 64, 64, 256)  1024        leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 64, 64, 256)  590080      batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)       (None, 64, 64, 256)  0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 64, 64, 256)  1024        leaky_re_lu_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 32, 32, 256)  0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 32, 32, 512)  1180160     max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)       (None, 32, 32, 512)  0           conv2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 32, 32, 512)  2048        leaky_re_lu_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 32, 32, 512)  2359808     batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)       (None, 32, 32, 512)  0           conv2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 32, 32, 512)  2048        leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 32, 32, 512)  0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 16, 16, 512)  0           dropout[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 16, 16, 1024) 4719616     max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)       (None, 16, 16, 1024) 0           conv2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 16, 16, 1024) 4096        leaky_re_lu_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 16, 16, 1024) 9438208     batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)       (None, 16, 16, 1024) 0           conv2d_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 16, 16, 1024) 4096        leaky_re_lu_9[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 16, 16, 1024) 0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# up_sampling2d (UpSampling2D)    (None, 32, 32, 1024) 0           dropout_1[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 32, 32, 512)  2097664     up_sampling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 32, 32, 512)  2048        conv2d_10[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 32, 32, 1024) 0           dropout[0][0]
#                                                                  batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 32, 32, 512)  4719104     concatenate[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 32, 32, 512)  2048        conv2d_11[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 32, 32, 512)  2359808     batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 32, 32, 512)  2048        conv2d_12[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, 64, 64, 512)  0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 64, 64, 256)  524544      up_sampling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 64, 64, 256)  1024        conv2d_13[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 64, 64, 512)  0           batch_normalization_5[0][0]
#                                                                  batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 64, 64, 256)  1179904     concatenate_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 64, 64, 256)  1024        conv2d_14[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 64, 64, 256)  590080      batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 64, 64, 256)  1024        conv2d_15[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (None, 128, 128, 256 0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 128, 128, 128 131200      up_sampling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 128, 128, 128 512         conv2d_16[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 128, 128, 256 0           batch_normalization_3[0][0]
#                                                                  batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 128, 128, 128 295040      concatenate_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 128, 128, 128 512         conv2d_17[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 128, 128, 128 147584      batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 128, 128, 128 512         conv2d_18[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_3 (UpSampling2D)  (None, 256, 256, 128 0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 256, 256, 64) 32832       up_sampling2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 256, 256, 64) 256         conv2d_19[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 256, 256, 128 0           batch_normalization_1[0][0]
#                                                                  batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 256, 256, 64) 73792       concatenate_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 256, 256, 64) 256         conv2d_20[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 256, 256, 64) 36928       batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 256, 256, 64) 256         conv2d_21[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 256, 256, 4)  2308        batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 256, 256, 4)  16          conv2d_22[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 256, 256, 4)  20          batch_normalization_22[0][0]
# ==================================================================================================
# Total params: 31,061,416
# Trainable params: 31,047,712
# Non-trainable params: 13,704
# __________________________________________________________________________________________________
# None
# Found 29 images belonging to 1 classes.
# Found 29 images belonging to 1 classes.
# Epoch 1/2
# 2048/2048 [==============================] - 632s 309ms/step - loss: 0.5273 - acc: 0.9517
# Epoch 2/2
# 2048/2048 [==============================] - 640s 313ms/step - loss: 0.3185 - acc: 0.9820

# %%
from segHelperLib import *
results = testUnet(COLOR_DICT , modelPath = './model_archive/segmentation_09_03_16_01.hdf5', multiLabel=True)
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0903 16:42:40.348000  6360 deprecation_wrapper.py:119] From C:\Users\Zifeng Li\Desktop\HelmsleyDocker\Helmsley3DMIP\_Scripts\Utilities\manualSegHelper\test_model.py:4: The name tf.keras.layers.CuDNNGRU is deprecated. Please use tf.compat.v1.keras.layers.CuDNNGRU instead.
#
# W0903 16:42:40.351000  6360 deprecation_wrapper.py:119] From C:\Users\Zifeng Li\Desktop\HelmsleyDocker\Helmsley3DMIP\_Scripts\Utilities\manualSegHelper\test_model.py:4: The name tf.keras.layers.CuDNNLSTM is deprecated. Please use tf.compat.v1.keras.layers.CuDNNLSTM instead.
#
# W0903 16:42:41.129032  6360 deprecation.py:506] From C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\tensorflow\python\ops\init_ops.py:1288: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 1875177060654940540
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 6667611669
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 8953093617491668941
# physical_device_desc: "device: 0, name: GeForce GTX 1080, pci bus id: 0000:01:00.0, compute capability: 6.1"
# ]
# W0903 16:42:42.253999  6360 deprecation.py:323] From C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\tensorflow\python\ops\nn_impl.py:180: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 256, 256, 64) 1792        input_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu (LeakyReLU)         (None, 256, 256, 64) 0           conv2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 256, 256, 64) 256         leaky_re_lu[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 256, 256, 64) 36928       batch_normalization[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)       (None, 256, 256, 64) 0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 256, 256, 64) 256         leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 128, 128, 64) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 128, 128, 128 73856       max_pooling2d[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)       (None, 128, 128, 128 0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 128, 128, 128 512         leaky_re_lu_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 128, 128, 128 147584      batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)       (None, 128, 128, 128 0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 128, 128, 128 512         leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 64, 64, 128)  0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 64, 64, 256)  295168      max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)       (None, 64, 64, 256)  0           conv2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 64, 64, 256)  1024        leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 64, 64, 256)  590080      batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)       (None, 64, 64, 256)  0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 64, 64, 256)  1024        leaky_re_lu_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 32, 32, 256)  0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 32, 32, 512)  1180160     max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)       (None, 32, 32, 512)  0           conv2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 32, 32, 512)  2048        leaky_re_lu_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 32, 32, 512)  2359808     batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)       (None, 32, 32, 512)  0           conv2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 32, 32, 512)  2048        leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 32, 32, 512)  0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 16, 16, 512)  0           dropout[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 16, 16, 1024) 4719616     max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)       (None, 16, 16, 1024) 0           conv2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 16, 16, 1024) 4096        leaky_re_lu_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 16, 16, 1024) 9438208     batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)       (None, 16, 16, 1024) 0           conv2d_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 16, 16, 1024) 4096        leaky_re_lu_9[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 16, 16, 1024) 0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# up_sampling2d (UpSampling2D)    (None, 32, 32, 1024) 0           dropout_1[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 32, 32, 512)  2097664     up_sampling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 32, 32, 512)  2048        conv2d_10[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 32, 32, 1024) 0           dropout[0][0]
#                                                                  batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 32, 32, 512)  4719104     concatenate[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 32, 32, 512)  2048        conv2d_11[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 32, 32, 512)  2359808     batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 32, 32, 512)  2048        conv2d_12[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, 64, 64, 512)  0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 64, 64, 256)  524544      up_sampling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 64, 64, 256)  1024        conv2d_13[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 64, 64, 512)  0           batch_normalization_5[0][0]
#                                                                  batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 64, 64, 256)  1179904     concatenate_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 64, 64, 256)  1024        conv2d_14[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 64, 64, 256)  590080      batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 64, 64, 256)  1024        conv2d_15[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (None, 128, 128, 256 0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 128, 128, 128 131200      up_sampling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 128, 128, 128 512         conv2d_16[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 128, 128, 256 0           batch_normalization_3[0][0]
#                                                                  batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 128, 128, 128 295040      concatenate_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 128, 128, 128 512         conv2d_17[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 128, 128, 128 147584      batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 128, 128, 128 512         conv2d_18[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_3 (UpSampling2D)  (None, 256, 256, 128 0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 256, 256, 64) 32832       up_sampling2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 256, 256, 64) 256         conv2d_19[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 256, 256, 128 0           batch_normalization_1[0][0]
#                                                                  batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 256, 256, 64) 73792       concatenate_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 256, 256, 64) 256         conv2d_20[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 256, 256, 64) 36928       batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 256, 256, 64) 256         conv2d_21[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 256, 256, 4)  2308        batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 256, 256, 4)  16          conv2d_22[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 256, 256, 4)  20          batch_normalization_22[0][0]
# ==================================================================================================
# Total params: 31,061,416
# Trainable params: 31,047,712
# Non-trainable params: 13,704
# __________________________________________________________________________________________________
# None
# 116/116 [==============================] - 6s 48ms/step
# Successfully created the directory ./predicted_segmnetation_09_03_16_42
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_03_16_42\0_predict.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_03_16_42\1_predict.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_03_16_42\2_predict.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_03_16_42\3_predict.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_03_16_42\4_predict.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_03_16_42\5_predict.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_03_16_42\6_predict.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_03_16_42\7_predict.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_03_16_42\8_predict.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_03_16_42\9_predict.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_03_16_42\10_predict.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_03_16_42\11_predict.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_03_16_42\12_predict.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_03_16_42\13_predict.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_03_16_42\14_predict.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_03_16_42\15_predict.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_03_16_42\16_predict.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_03_16_42\17_predict.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_03_16_42\18_predict.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_03_16_42\19_predict.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_03_16_42\20_predict.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_03_16_42\21_predict.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_03_16_42\22_predict.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_03_16_42\23_predict.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_03_16_42\24_predict.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_03_16_42\25_predict.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_03_16_42\26_predict.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_03_16_42\27_predict.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_03_16_42\103_predict.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_03_16_42\104_predict.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_03_16_42\105_predict.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_03_16_42\106_predict.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_03_16_42\107_predict.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_03_16_42\108_predict.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_03_16_42\109_predict.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_03_16_42\110_predict.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_03_16_42\111_predict.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_03_16_42\112_predict.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_03_16_42\113_predict.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_03_16_42\114_predict.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# C:\Users\Zifeng Li\Anaconda3\envs\Helmsley3DMIP\lib\site-packages\skimage\io\_io.py:141: UserWarning: ./predicted_segmnetation_09_03_16_42\115_predict.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
