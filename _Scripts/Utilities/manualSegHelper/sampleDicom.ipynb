# %%
from segHelperLib import *
import os
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0924 16:56:55.502732 16984 deprecation_wrapper.py:119] From C:\Users\Zifeng Li\Desktop\HelmsleyDocker\Helmsley3DMIP\_Scripts\Utilities\manualSegHelper\test_model.py:4: The name tf.keras.layers.CuDNNGRU is deprecated. Please use tf.compat.v1.keras.layers.CuDNNGRU instead.
#
# W0924 16:56:55.505703 16984 deprecation_wrapper.py:119] From C:\Users\Zifeng Li\Desktop\HelmsleyDocker\Helmsley3DMIP\_Scripts\Utilities\manualSegHelper\test_model.py:4: The name tf.keras.layers.CuDNNLSTM is deprecated. Please use tf.compat.v1.keras.layers.CuDNNLSTM instead.

# %%
# Run this block to prepare all the training data
pruneSystem()
sampleDicomData(0.3, 1)
# Out:
# Deleting old training files and temp files.
# Successfully created the directory ./sampledDataset
# Sampling 16 dicom images.

# %%
# Out:
# .\.ipynb_checkpoints\sampleDicom-checkpoint.ipynb
# .\.ipynb_checkpoints\segmentationTool-checkpoint.ipynb
# .\.ipynb_checkpoints\segmentationToolPng-checkpoint.ipynb
# .\.ipynb_checkpoints\Untitled-checkpoint.ipynb
# .\model_archive\README.md
# .\model_archive\segmentation_09_03_14_28.hdf5
# .\model_archive\segmentation_09_03_16_01.hdf5
# .\model_archive\segmentation_09_09_15_48_new_lava.hdf5
# .\model_archive\segmentation_09_11_16_18_2016_splean.hdf5
# .\model_archive\segmentation_09_11_18_26.hdf5
# .\model_archive\segmentation_09_12_12_07.hdf5
# .\model_archive\segmentation_09_18_13_34.hdf5
# .\model_archive\segmentation_09_18_17_05.hdf5
# .\model_archive\segmentation_09_20_15_40.hdf5
# .\mri_2017_dicom\Z848.dcm
# .\mri_2017_dicom\Z849.dcm
# .\mri_2017_dicom\Z850.dcm
# .\mri_2017_dicom\Z851.dcm
# .\mri_2017_dicom\Z852.dcm
# .\mri_2017_dicom\Z853.dcm
# .\mri_2017_dicom\Z854.dcm
# .\mri_2017_dicom\Z855.dcm
# .\mri_2017_dicom\Z856.dcm
# .\mri_2017_dicom\Z857.dcm
# ...
