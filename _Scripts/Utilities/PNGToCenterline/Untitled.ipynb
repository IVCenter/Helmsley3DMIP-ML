# %%
from centerlineLib import *

# %%
testCenterline = centerlineComputor()
centerlineCor = testCenterline.getCenterline(".\\New_820_Lava_Cor_pre_mask\*.png", 1, True)
# Out:
# Done!
# ---------------
# There are 562443 points in total. Now sampleling 7000 points from them
# ---------------
# Done!
# ---------------
# Begin creating a MST of the sampled points cloud
# ---------------
# Begin calculating nearby points for each point
# ---------------
# Nearby points calculation Done! Total: 7000 points, 168000 edges.
# ---------------
# Begin construct graph
# ---------------
# Graph construction Done!
# ---------------
# Begin calculate MST
# ---------------
# MST calculation Done!
# ---------------
# MST creation Done!
#   0% (3 of 7000) |                       | Elapsed Time: 0:00:00 ETA:   0:05:14
# Start centerline iteration: 0
#   9% (636 of 7000) |#                    | Elapsed Time: 0:00:14 ETA:   0:02:22
# Overflow!
#  37% (2635 of 7000) |#######             | Elapsed Time: 0:00:59 ETA:   0:01:26
# Overflow!
# 100% (7000 of 7000) |####################| Elapsed Time: 0:02:38 Time:  0:02:38
# ...
